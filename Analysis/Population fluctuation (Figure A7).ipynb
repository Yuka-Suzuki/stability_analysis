# %%
import numpy as np
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.feature_selection import *
import seaborn as sns
from scipy import stats
import warnings
from numpy import median
from matplotlib.pyplot import cm
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Population fluctuation (sp5 population in each patch) for default setting with different d=0.001, 0.01, 0.1.

# %%
sp5_d0001_sw500 = np.loadtxt("populations_visualization/population_sp5_SmallWorld_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.001_r0.7",skiprows=1)
sp5_d001_sw500 = np.loadtxt("populations_visualization/population_sp5_SmallWorld_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.01_r0.7",skiprows=1)
sp5_d01_sw500 = np.loadtxt("populations_visualization/population_sp5_SmallWorld_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.1_r0.7",skiprows=1)
plt.rcParams.update({'font.size':18,'font.family':'arial'})
sns.set()
fig, axs = plt.subplots(3,1,figsize=(10,7))
x = range(4000)
n_com = 10
_=axs[0].plot((sp5_d0001_sw500[:n_com]).T)
_=axs[1].plot((sp5_d001_sw500[:n_com]).T)
_=axs[2].plot((sp5_d01_sw500[:n_com]).T)
_=axs[0].set_ylim([-0.05,1.5])
_=axs[1].set_ylim([-0.05,1.5])
_=axs[2].set_ylim([-0.05,1.5])
_=axs[0].set_xticks([],[])
_=axs[1].set_xticks([],[])
#_=axs[0].axis('off')
#_=axs[1].axis('off')
_=plt.suptitle('SmallWorld network')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.rcParams.update({'font.size':18,'font.family':'arial'})
sp5_d0001_comp500 = np.loadtxt("populations_visualization/population_sp5_Complete_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.001_r0.7",skiprows=1)
sp5_d001_comp500 = np.loadtxt("populations_visualization/population_sp5_Complete_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.01_r0.7",skiprows=1)
sp5_d01_comp500 = np.loadtxt("populations_visualization/population_sp5_Complete_undir_N500e500_hetero0.8_fluc0.95_std1.0_d0.1_r0.7",skiprows=1)

fig, axs = plt.subplots(3,1,figsize=(10,7))
x = range(4000)
n_com = 10
_=axs[0].plot((sp5_d0001_sw500[:n_com]).T)
_=axs[1].plot((sp5_d001_sw500[:n_com]).T)
_=axs[2].plot((sp5_d01_sw500[:n_com]).T)
_=axs[0].set_ylim([-0.05,1.5])
_=axs[1].set_ylim([-0.05,1.5])
_=axs[2].set_ylim([-0.05,1.5])
_=axs[0].set_xticks([],[])
_=axs[1].set_xticks([],[])
_=plt.suptitle('Complete network')
# Out:
# <img src="data:image/png;base64,..." width="1000">
